# %% [markdown]
# # XAI for SVM model

# %% [markdown]
# Explainable AI (XAI) aims to make machine learning models more transparent by helping us understand how features influence model predictions. One powerful method for this is SHAP (SHapley Additive exPlanations), which uses concepts from cooperative game theory to fairly distribute the model’s output among input features. SHAP values explain how much each feature contributes to a specific prediction, offering both global and local interpretability. The SHAP Python package provides practical tools for interpreting a wide range of models—from linear regression to deep neural networks—making it a widely adopted choice for model explanation.

# %%
from XAI.XaiHeatmap import XaiHeatmap
from XAI.XaiBeeswarm import XaiBeeswarm
from XAI.XaiWaterfall import XaiWaterfall

# %% [markdown]
# ## Heatmap plot

# %% [markdown]
# The SHAP heatmap is a tool to visualize how input features influence model predictions across many samples.
#
#     X-axis: individual samples
#
#     Y-axis: input features
#
# Colors: SHAP values – showing how much each feature contributes to the prediction for each sample
#
#     Red = positive impact
#
#     Blue = negative impact
#
# Above the heatmap, model outputs are shown (centered on the base value). On the right, a bar plot shows each feature’s overall importance.
#
# Samples are automatically grouped by similarity in explanations, making patterns easier to spot. This helps identify common decision paths, unusual cases, and key drivers behind the model's behavior.

# %%
xai = XaiHeatmap()
xai.run()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# c:\Users\weral\Desktop\WIMU\projekt\AudioConcept_project\AudioConcept\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 2025-06-01 00:48:58.054 | WARNING  | AudioConcept.models.classifier_svm:__init__:70 - Failed to initialize wandb: API key must be 40 characters long, yours was 1
# 2025-06-01 00:48:58.054 | WARNING  | AudioConcept.models.classifier_svm:__init__:71 - Continuing without wandb logging...
# 2025-06-01 00:48:58.056 | INFO     | AudioConcept.models.classifier_svm:load_model:215 - Model loaded from C:\Users\weral\Desktop\WIMU\projekt\AudioConcept_project\AudioConcept\models\svm_genre_classifier.pkl
# PermutationExplainer explainer: 101it [01:06,  1.38it/s]

# %% [markdown]
# ## Beeswarm plot

# %% [markdown]
# The SHAP beeswarm plot provides a compact, information-rich summary of how the most important features influence a model’s predictions. Each dot represents an individual data instance’s SHAP value for a specific feature, with the dot’s horizontal position showing the impact on the model output. Dots stack vertically to indicate density, while their color reflects the original feature value. This visualization helps identify both feature importance and how different feature values affect the prediction.

# %%
xai = XaiBeeswarm()
xai.run()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# c:\Users\weral\Desktop\WIMU\projekt\AudioConcept_project\AudioConcept\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 2025-06-01 00:39:06.275 | WARNING  | AudioConcept.models.classifier_svm:__init__:70 - Failed to initialize wandb: API key must be 40 characters long, yours was 1
# 2025-06-01 00:39:06.276 | WARNING  | AudioConcept.models.classifier_svm:__init__:71 - Continuing without wandb logging...
# 2025-06-01 00:39:06.278 | INFO     | AudioConcept.models.classifier_svm:load_model:215 - Model loaded from C:\Users\weral\Desktop\WIMU\projekt\AudioConcept_project\AudioConcept\models\best_SVM_model.pkl
# PermutationExplainer explainer: 101it [00:55,  1.66it/s]

# %%
xai = XaiWaterfall()
xai.run()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# 2025-06-01 01:01:28.505 | WARNING  | AudioConcept.models.classifier_svm:__init__:70 - Failed to initialize wandb: API key must be 40 characters long, yours was 1
# 2025-06-01 01:01:28.506 | WARNING  | AudioConcept.models.classifier_svm:__init__:71 - Continuing without wandb logging...
# 2025-06-01 01:01:28.507 | INFO     | AudioConcept.models.classifier_svm:load_model:215 - Model loaded from C:\Users\weral\Desktop\WIMU\projekt\AudioConcept_project\AudioConcept\models\svm_genre_classifier.pkl
# PermutationExplainer explainer: 51it [00:29,  1.02it/s]
